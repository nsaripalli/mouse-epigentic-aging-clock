# %% [markdown]
# This notebook shows you how to create and query a table or DataFrame loaded from data stored in Azure Blob storage.

# %% [markdown]
# ### Step 1: Set the data location and type
#
# There are two ways to access Azure Blob storage: account keys and shared access signatures (SAS).
#
# To get started, we need to set the location and type of the file.

# %%
# import pandas as pd
import numpy as np
import pyspark.pandas as ps
from pyspark.pandas.config import option_context
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
Dstorage_account_name = "harry"
storage_account_access_key = "READACTED"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
file_location = "wasbs://cleaned/GSE52268_GSM1262166.CGfinal"
file_type = "csv"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
spark.conf.set(
  "fs.azure.account.key."+storage_account_name+".blob.core.windows.net",
  storage_account_access_key)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
GSE93957 = {
    "GSM2465615" :	41,
"GSM2465616" :	41,
"GSM2465617" :	41,
"GSM2465618" :	41,
"GSM2465619" :	41,
"GSM2465620" :	41,
"GSM2465621" :	41,
"GSM2465622" :	41,
"GSM2465623" :	41,
"GSM2465624" :	41,
"GSM2465625" :	41,
"GSM2465626" :	41,
"GSM2465627" :	41,
"GSM2465628" :	41,
"GSM2465629" :	41,
"GSM2465630" :	41,
"GSM2465631" :	27,
"GSM2465632" :	27,
"GSM2465633" :	27,
"GSM2465634" :	27,
"GSM2465635" :	27,
"GSM2465636" :	27,
"GSM2465637" :	27,
"GSM2465638" :	27,
"GSM2465639" :	27,
"GSM2465640" :	27,
"GSM2465641" :	27,
"GSM2465642" :	27,
"GSM2465643" :	27,
"GSM2465644" :	27,
"GSM2465645" :	27,
"GSM2465646" :	27,
"GSM2465647" :	1,
"GSM2465648" :	1,
"GSM2465649" :	1,
"GSM2465650" :	1,
"GSM2465651" :	1,
"GSM2465652" :	1,
"GSM2465653" :	1,
"GSM2465654" :	1,
"GSM2465655" :	1,
"GSM2465656" :	1,
"GSM2465657" :	14,
"GSM2465658" :	14,
"GSM2465659" :	14,
"GSM2465660" :	14,
"GSM2465661" :	14,
"GSM2465662" :	14,
"GSM2465663" :	14,
"GSM2465664" :	14,
"GSM2465665" :	1,
"GSM2465666" :	1,
"GSM2465667" :	1,
"GSM2465668" :	1,
"GSM2465669" :	27,
"GSM2465670" :	27,
"GSM2465671" :	27,
"GSM2465672" :	27,
"GSM2465673" :	14,
"GSM2465674" :	14,
"GSM2465675" :	14,
"GSM2465676" :	14,
}

GSE52268 = {
    "GSM1262165":	9,
"GSM1262166":	9,
"GSM1262167":	9,
"GSM1262168":	9,
"GSM1262169":	9,
"GSM1262170":	9,
"GSM1262171":	9,
"GSM1262172":	9,
"GSM1262173":	9,
"GSM1262174":	9,
"GSM1262175":	9,
"GSM1262176":	9,
"GSM1262177":	9,
"GSM1262178":	9,
"GSM1262179":	9,
"GSM1262180":	9,
"GSM1262181":	9,
"GSM1262182":	9,
"GSM1262183":	9,
"GSM1262184":	9,
"GSM1262185":	9,
"GSM1262186":	9,
"GSM1262187":	9,
"GSM1262188":	9,
"GSM1262189":	9,
"GSM1262190":	9,
"GSM1262191":	9,
"GSM1262192":	9,
"GSM1262193":	9,
"GSM1262194":	9,
"GSM1262195":	9,
"GSM1262196":	9,
"GSM1262197":	9,
"GSM1262198":	9,
"GSM1262199":	9,
"GSM1262200":	9,
"GSM1262201":	9,
"GSM1262202":	9,
"GSM1262203":	9,
"GSM1262204":	9,
"GSM2363485": 2,
"GSM2363486": 22,
"GSM2363487": 22,
"GSM2363488": 22,
"GSM2363489": 22,
"GSM2363490": 22,
"GSM2363491": 22,
"GSM2363492": 22,
"GSM2363493": 22,
"GSM2363494": 2,
"GSM2363495": 2,
"GSM2363496": 2,
"GSM2363497": 2,
"GSM2363498": 2,
"GSM2363499": 2,
"GSM2363500": 2,
"GSM2363501": 2,
"GSM2363502": 2,
"GSM2363503": 2,
"GSM2363504": 2,
"GSM2363505": 2,
"GSM2363506": 22,
"GSM2363507": 22,
"GSM2363508": 22,
"GSM2363509": 22,
"GSM2363510": 22,
"GSM2363511": 22,
"GSM2363512": 22,
"GSM2363513": 22,
"GSM2363514": 22,
"GSM2363515": 22,
"GSM2363516": 22,
"GSM2363517": 22,

}


for k,v in GSE89275.items():
  # months * avg weeks in a month
  GSE89275[k] = v * 4.345
lookup = {**GSE52268, **GSE58129 , **GSE67507, **GSE80672 , **GSE85251 , **GSE89275, **GSE93957}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Step 2: Read the data
#
# Now that we have specified our file metadata, we can create a DataFrame. Notice that we use an *option* to specify that we want to infer the schema from the file. We can also explicitly set this to a particular schema if we have one already.
#
# First, let's create a DataFrame in Python.

# %%
# df = ps.read_csv(str(file_location), sep=" ",header=None, names=["chromosome", "dinucleotide", "position", "methylated counts", "total counts", "methylation frequency", "95% confidence interval for methylation frequency"], dtype={"methylation frequency": np.float32},)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">Py4JJavaError</span>                             Traceback (most recent call last)
# ...

# %%
# files = [dbfs:/FileStore/shared_uploads/saripalli.n@northeastern.edu/GSE52268_GSM1262167.CGfinal
# dbfs:/FileStore/shared_uploads/saripalli.n@northeastern.edu/GSE52268_GSM1262166.CGfinal
# dbfs:/FileStore/shared_uploads/saripalli.n@northeastern.edu/GSE52268_GSM1262165.CGfinal]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# from pathlib import Path

# x = Path('/dbfs/FileStore/shared_uploads/saripalli.n@northeastern.edu').rglob("*.CGfinal")
# list(x)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# x =  dbutils.fs.ls("wasbs://newcontainer@harry.blob.core.windows.net/cleaned")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# x[0].name.split(".")[0].split("_")[1]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# import os
# os.remove("/dbfs/FileStore/shared_uploads/saripalli.n@northeastern.edu/"+"GSE52268_GSM1262167"+".CGfinal")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
import string
ascii_index = dict(list([reversed(i) for i in list(enumerate(list(string.printable)))]))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dfs = []
stop = 10
for path in dbutils.fs.ls("wasbs://newcontainer@harry.blob.core.windows.net/cleaned"):
  if stop == 0:
    break
  if path.name.split(".")[0].split("_")[1] not in lookup.keys():
    print("skipping: ", path.name)
    continue
  print(path)
  df = ps.read_csv(path.path, sep=" ",header=None, names=["chromosome", "dinucleotide", "position", "methylated counts", "total counts", "methylation frequency", "95% confidence interval for methylation frequency"], dtype={"methylation frequency": np.float32},)
  df = df[df['methylated counts'] >= 5]

  df["location"] = df["chromosome"].str.slice(start=-1).replace(ascii_index).astype(np.int64) + (df["position"].astype(np.int64) * 1000)
  df = df[["location", "methylation frequency"]].set_index("location")
  df = df.rename(columns={"methylation frequency":  str(path.name)})
  #     
  #         df = df.T
  #     df["age"] = int(lookup[path.name.split("_")[1].split(".")[0]])
  #     df["path"] = str(path.name)
  #     df = df.set_index("path")
  dfs.append(df)
  stop -= 1
  
# merged = ps.concat(dfs)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">FileInfo(path=&#39;wasbs://newcontainer@harry.blob.core.windows.net/cleaned/GSE52268_GSM1262165.CGfinal&#39;, name=&#39;GSE52268_GSM1262165.CGfinal&#39;, size=46676447, modificationTime=1651241274000)
# FileInfo(path=&#39;wasbs://newcontainer@harry.blob.core.windows.net/cleaned/GSE52268_GSM1262166.CGfinal&#39;, name=&#39;GSE52268_GSM1262166.CGfinal&#39;, size=52155416, modificationTime=1651240612000)
# FileInfo(path=&#39;wasbs://newcontainer@harry.blob.core.windows.net/cleaned/GSE52268_GSM1262167.CGfinal&#39;, name=&#39;GSE52268_GSM1262167.CGfinal&#39;, size=49541093, modificationTime=1651240391000)
# ...

# %%
len(dfs)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[13]: 10</div>

# %%
from functools import reduce
df_final = reduce(lambda left,right: left.join(right), dfs)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_final.spark.explain()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">== Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- Project [location#182L, GSE52268_GSM1262165.CGfinal#183, GSE52268_GSM1262166.CGfinal#3544, GSE52268_GSM1262167.CGfinal#3579, GSE52268_GSM1262168.CGfinal#3620, GSE52268_GSM1262169.CGfinal#3667, GSE52268_GSM1262170.CGfinal#3720, GSE52268_GSM1262171.CGfinal#3779, GSE52268_GSM1262172.CGfinal#3844, GSE52268_GSM1262173.CGfinal#3915, __right_GSE52268_GSM1262174.CGfinal#3960 AS GSE52268_GSM1262174.CGfinal#3992]
#    +- SortMergeJoin [location#182L], [__right_location#3959L], LeftOuter
# ...

# %%
x = df_final
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df = ps.read_csv(path.path, sep=" ",header=None, names=["chromosome", "dinucleotide", "position", "methylated counts", "total counts", "methylation frequency", "95% confidence interval for methylation frequency"], dtype={"methylation frequency": np.float32},)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dfs[0].head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[52]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>GSE52268_GSM1262165.CGfinal</th>
#     </tr>
#     <tr>
#       <th>location</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>3037802001</th>
#       <td>0.91</td>
#     </tr>
#     <tr>
# ...

# %%
list(df_final.columns)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[61]: [&#39;GSE52268_GSM1262165.CGfinal&#39;,
#  &#39;GSE52268_GSM1262166.CGfinal&#39;,
#  &#39;GSE52268_GSM1262167.CGfinal&#39;,
#  &#39;GSE52268_GSM1262168.CGfinal&#39;,
#  &#39;GSE52268_GSM1262169.CGfinal&#39;,
#  &#39;GSE52268_GSM1262170.CGfinal&#39;,
#  &#39;GSE52268_GSM1262171.CGfinal&#39;,
#  &#39;GSE52268_GSM1262172.CGfinal&#39;,
#  &#39;GSE52268_GSM1262173.CGfinal&#39;,
#  &#39;GSE52268_GSM1262174.CGfinal&#39;]</div>

# %%
spark.conf.set('spark.sql.pivotMaxValues', u'999999')
df_final.pivot(columns="location", values=list(df_final.columns))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
df_t = None
with option_context('compute.max_rows', 9999999):
  df_t = df_final.T
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import quantile_transform
from sklearn.preprocessing import StandardScaler
from sklearn import linear_model
from sklearn.linear_model import ElasticNet
from sklearn.model_selection import cross_validate
from sklearn.metrics import mean_squared_error, r2_score


y = train.pop("weeks")
X = train

X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
import numpy as np

y_train = np.log(y_train)
y_test = np.log(y_test)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
X_train = quantile_transform(X_train, n_quantiles=10, random_state=0)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
X_test = quantile_transform(X_test, n_quantiles=10, random_state=0)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
scaler = StandardScaler()
sc = scaler.fit(X)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
X_train = sc.transform(X_train)
X_test = sc.transform(X_test)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
elastic = ElasticNet()
cv_results = cross_validate(elastic, X_train, y_train, cv=3, scoring="neg_mean_squared_error", return_train_score=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
cv_results
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
y_pred = reg.predict(X_test)
print("Mean squared error: %.2f" % mean_squared_error(list(y_test), y_pred))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
